# %%
from datetime import date, datetime

print(date)
# Out:
# <class 'datetime.date'>

# %%
print(date.today())
# Out:
# 2022-06-07

# %%
from playwright.sync_api import sync_playwright
from playwright.async_api import async_playwright
# from playwright_stealth import stealth_sync
import asyncio

async def run(pw):

    browser = await pw.chromium.launch(headless=False)
    # context = browser.new_context(
    #     user_agent=ua,
    # )


    url = 'https://anilife.live/h/live?p=5aaf4907-da62-4b98-ba8f-59066a0dc0f4&a=none&player=jawcloud'
    #
    # if referer is not None:
    #     LogicAniLife.headers["Referer"] = referer

    # context = browser.new_context(extra_http_headers=LogicAniLife.headers)
    context = await browser.new_context()
    # LogicAniLife.headers["Cookie"] = cookie_value

    # context.set_extra_http_headers(LogicAniLife.headers)

    page = await context.new_page()



    # page.on("request", set_cookie)
    # stealth_sync(page)
    page.goto(
        url, wait_until="networkidle"
    )
    page.wait_for_timeout(10000)
    # time.sleep(1)
    # page.reload()

    # time.sleep(10)
    cookies = context.cookies
    # print(cookies)

    # print(page.content())
    vod_url = page.evaluate(
        """() => {
        return console.log(vodUrl_1080p) }"""
    )
    print(vod_url)

async def main():
    async with async_playwright() as p:
        await main_run(p)


asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/9l/5sls926d02g2kzqb70_0c7rc0000gn/T/ipykernel_40530/2714877972.py in <module>
#      52
#      53
# ---> 54 asyncio.run(main())
#
# /Volumes/WD/Users/yommi/miniforge3/envs/ani-downloader/lib/python3.8/asyncio/runners.py in run(main, debug)
#      31     """
#      32     if events._get_running_loop() is not None:
# ---> 33         raise RuntimeError(
#      34             "asyncio.run() cannot be called from a running event loop")
#      35
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
# !playwright install

from playwright.sync_api import sync_playwright
from playwright.async_api import async_playwright
# from playwright_stealth import stealth_sync
import asyncio
import nest_asyncio
nest_asyncio.apply()


async def main_run(playwright):

    browser = await playwright.chromium.launch(headless=False)
    # context = browser.new_context(
    #     user_agent=ua,
    # )


    url = 'https://sir.kr'
    #
    # if referer is not None:
    #     LogicAniLife.headers["Referer"] = referer

    # context = browser.new_context(extra_http_headers=LogicAniLife.headers)
    context = await browser.new_context()
    # LogicAniLife.headers["Cookie"] = cookie_value

    # context.set_extra_http_headers(LogicAniLife.headers)

    page = await context.new_page()



    # page.on("request", set_cookie)
    # stealth_sync(page)
    page.goto(
        url, wait_until="networkidle"
    )
    page.wait_for_timeout(10000)
    # time.sleep(1)
    # page.reload()

    # time.sleep(10)
    cookies = context.cookies
    # print(cookies)

    # print(page.content())
    vod_url = page.evaluate(
        """() => {
        return console.log(vodUrl_1080p) }"""
    )
    print(vod_url)

async def main():
    async with async_playwright() as p:
        await main_run(p)


asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /var/folders/9l/5sls926d02g2kzqb70_0c7rc0000gn/T/ipykernel_67283/2756312828.py in <module>
#      57
#      58
# ---> 59 asyncio.run(main())
#
# /Volumes/WD/Users/yommi/miniforge3/envs/ani-downloader/lib/python3.8/site-packages/nest_asyncio.py in run(future, debug)
#      30         loop = asyncio.get_event_loop()
#      31         loop.set_debug(debug)
# ---> 32         return loop.run_until_complete(future)
#      33
#      34     if sys.version_info >= (3, 6, 0):
#
# /Volumes/WD/Users/yommi/miniforge3/envs/ani-downloader/lib/python3.8/site-packages/nest_asyncio.py in run_until_complete(self, future)
#      68                 raise RuntimeError(
#      69                     'Event loop stopped before Future completed.')
# ---> 70             return f.result()
#      71
#      72     def _run_once(self):
#
# /Volumes/WD/Users/yommi/miniforge3/envs/ani-downloader/lib/python3.8/asyncio/futures.py in result(self)
#     176         self.__log_traceback = False
#     177         if self._exception is not None:
# --> 178             raise self._exception
#     179         return self._result
#     180
#
# /Volumes/WD/Users/yommi/miniforge3/envs/ani-downloader/lib/python3.8/asyncio/tasks.py in __step(***failed resolving arguments***)
#     278                 # We use the `send` method directly, because coroutines
#     279                 # don't have `__iter__` and `__next__` methods.
# --> 280                 result = coro.send(None)
#     281             else:
#     282                 result = coro.throw(exc)
#
# /var/folders/9l/5sls926d02g2kzqb70_0c7rc0000gn/T/ipykernel_67283/2756312828.py in main()
#      54 async def main():
#      55     async with async_playwright() as p:
# ---> 56         await main_run(p)
#      57
#      58
#
# /var/folders/9l/5sls926d02g2kzqb70_0c7rc0000gn/T/ipykernel_67283/2756312828.py in main_run(playwright)
#      11 async def main_run(playwright):
#      12
# ---> 13     browser = await playwright.chromium.launch(headless=False)
#      14     # context = browser.new_context(
#      15     #     user_agent=ua,
#
# /Volumes/WD/Users/yommi/miniforge3/envs/ani-downloader/lib/python3.8/site-packages/playwright/async_api/_generated.py in launch(self, executable_path, channel, args, ignore_default_args, handle_sigint, handle_sigterm, handle_sighup, timeout, env, headless, devtools, proxy, downloads_path, slow_mo, traces_dir, chromium_sandbox, firefox_user_prefs)
#   11600
#   11601         return mapping.from_impl(
# > 11602             await self._async(
#   11603                 "browser_type.launch",
#   11604                 self._impl_obj.launch(
#
# /Volumes/WD/Users/yommi/miniforge3/envs/ani-downloader/lib/python3.8/site-packages/playwright/_impl/_browser_type.py in launch(self, executablePath, channel, args, ignoreDefaultArgs, handleSIGINT, handleSIGTERM, handleSIGHUP, timeout, env, headless, devtools, proxy, downloadsPath, slowMo, tracesDir, chromiumSandbox, firefoxUserPrefs)
#      86         params = locals_to_params(locals())
#      87         normalize_launch_params(params)
# ---> 88         return from_channel(await self._channel.send("launch", params))
#      89
#      90     async def launch_persistent_context(
#
# /Volumes/WD/Users/yommi/miniforge3/envs/ani-downloader/lib/python3.8/site-packages/playwright/_impl/_connection.py in send(self, method, params)
#      37
#      38     async def send(self, method: str, params: Dict = None) -> Any:
# ---> 39         return await self.inner_send(method, params, False)
#      40
#      41     async def send_return_as_dict(self, method: str, params: Dict = None) -> Any:
#
# /Volumes/WD/Users/yommi/miniforge3/envs/ani-downloader/lib/python3.8/site-packages/playwright/_impl/_connection.py in inner_send(self, method, params, return_as_dict)
#      61         if not callback.future.done():
#      62             callback.future.cancel()
# ---> 63         result = next(iter(done)).result()
#      64         # Protocol now has named return values, assume result is one level deeper unless
#      65         # there is explicit ambiguity.
#
# /Volumes/WD/Users/yommi/miniforge3/envs/ani-downloader/lib/python3.8/asyncio/futures.py in result(self)
#     176         self.__log_traceback = False
#     177         if self._exception is not None:
# --> 178             raise self._exception
#     179         return self._result
#     180
#
# Error: Executable doesn't exist at /Users/yommi/Library/Caches/ms-playwright/chromium-939194/chrome-mac/Chromium.app/Contents/MacOS/Chromium
# ╔═════════════════════════════════════════════════════════════════════════╗
# ║ Looks like Playwright Test or Playwright was just installed or updated. ║
# ║ Please run the following command to download new browsers:              ║
# ║                                                                         ║
# ║     playwright install                                                  ║
# ║                                                                         ║
# ║ <3 Playwright Team                                                      ║
# ╚═════════════════════════════════════════════════════════════════════════╝

# %%
import select

print(select)
# Out:
# <module 'select' from '/Users/yommi/.pyenv/versions/3.10.7/lib/python3.10/lib-dynload/select.cpython-310-darwin.so'>

# %%
print(dir(select))
# Out:
# ['KQ_EV_ADD', 'KQ_EV_CLEAR', 'KQ_EV_DELETE', 'KQ_EV_DISABLE', 'KQ_EV_ENABLE', 'KQ_EV_EOF', 'KQ_EV_ERROR', 'KQ_EV_FLAG1', 'KQ_EV_ONESHOT', 'KQ_EV_SYSFLAGS', 'KQ_FILTER_AIO', 'KQ_FILTER_PROC', 'KQ_FILTER_READ', 'KQ_FILTER_SIGNAL', 'KQ_FILTER_TIMER', 'KQ_FILTER_VNODE', 'KQ_FILTER_WRITE', 'KQ_NOTE_ATTRIB', 'KQ_NOTE_CHILD', 'KQ_NOTE_DELETE', 'KQ_NOTE_EXEC', 'KQ_NOTE_EXIT', 'KQ_NOTE_EXTEND', 'KQ_NOTE_FORK', 'KQ_NOTE_LINK', 'KQ_NOTE_LOWAT', 'KQ_NOTE_PCTRLMASK', 'KQ_NOTE_PDATAMASK', 'KQ_NOTE_RENAME', 'KQ_NOTE_REVOKE', 'KQ_NOTE_TRACK', 'KQ_NOTE_TRACKERR', 'KQ_NOTE_WRITE', 'PIPE_BUF', 'POLLERR', 'POLLHUP', 'POLLIN', 'POLLNVAL', 'POLLOUT', 'POLLPRI', 'POLLRDBAND', 'POLLRDNORM', 'POLLWRBAND', 'POLLWRNORM', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'error', 'kevent', 'kqueue', 'poll', 'select']

# %%
import attr

_kqueue = attr.ib(factory=select.kqueue)

print(_kqueue)
# Out:
# _CountingAttr(counter=23, _default=Factory(factory=<class 'select.kqueue'>, takes_self=False), repr=True, eq=True, order=True, hash=None, init=True, on_setattr=None, metadata={})

# %%
import os

t_str = "/data/anime_downloader/ohli24/용사 파티에서 추방된 비스트테이머, 최강종의 고양이귀 소녀와 만나다/Season 1/용사 파티에서 추방된 비스트테이머, 최강종의 고양이귀 소녀와 만나다.S01E06.1080p-OHNI24.mp4"

filename = os.path.basename(t_str)
print(filename)
# Out:
# 용사 파티에서 추방된 비스트테이머, 최강종의 고양이귀 소녀와 만나다.S01E06.1080p-OHNI24.mp4

# %%
srt_url = "https://cdn1-nydoodle.xyz/cdn/down/e2dbe79957ca1ba094c80cfd4c7604cb/thumbnails.vtt"

print(srt_url.split('/')[-1])
# Out:
# thumbnails.vtt
